# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import pandas as pd
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
   
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
     


        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lat=[]
lng=[]
temp=[]
hum=[]
cloud=[]
wind=[]
name=[]
units="imperial"
for city in cities:
    try:
        url="http://api.openweathermap.org/data/2.5/weather?q="+city+"&appid="+api_key+"&units="+units
        response=requests.get(url).json()
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp"])
        hum.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        name.append(response["name"])
        print(city)
        
      
    
    except Exception:
        print("There is no information for this city: "+city)
# Out:
# upernavik
# arraial do cabo
# talnakh
# dafeng
# hobart
# hilo
# khatanga
# qaanaaq
# chumikan
# nome
# bredasdorp
# bafoulabe
# centralia
# kabompo
# There is no information for this city: skalistyy
# punta arenas
# hofn
# lensk
# manaure
# saint-augustin
# sao gabriel da cachoeira
# jamestown
# mataura
# oktyabrskoye
# ponta do sol
# ushuaia
# soyo
# hithadhoo
# aykhal
# There is no information for this city: sentyabrskiy
# camacha
# vaini
# monrovia
# kapaa
# tiksi
# bambous virieux
# albany
# There is no information for this city: kashi
# luderitz
# gat
# saint-philippe
# zhangye
# butaritari
# bandarbeyla
# puerto ayora
# mount gambier
# necochea
# thompson
# mirnyy
# geraldton
# mozarlandia
# sampit
# yelan-koleno
# barrow
# east london
# atuona
# There is no information for this city: attawapiskat
# There is no information for this city: illoqqortoormiut
# rikitea
# rawson
# araouane
# bluff
# There is no information for this city: barentsburg
# cap malheureux
# ilulissat
# ribeira grande
# There is no information for this city: bengkulu
# There is no information for this city: jiddah
# kodiak
# There is no information for this city: umzimvubu
# There is no information for this city: balimo
# ancud
# fairbanks
# dikson
# grindavik
# menongue
# vostok
# lompoc
# ihosy
# busselton
# port-gentil
# turukhansk
# te anau
# lavrentiya
# sala
# boa vista
# castro
# broken hill
# luena
# auki
# aragarcas
# norman wells
# monterey
# takoradi
# popondetta
# There is no information for this city: taolanaro
# georgetown
# There is no information for this city: grand river south east
# naze
# rafaela
# new norfolk
# ternate
# siayan
# katsuura
# bure
# yuzhnyy
# killybegs
# maragogi
# There is no information for this city: tanshui
# port alfred
# bulawayo
# zhoucheng
# preobrazheniye
# avarua
# kruisfontein
# salalah
# cape town
# pochutla
# hermanus
# sao filipe
# cairns
# kavaratti
# chokurdakh
# presidencia roque saenz pena
# codrington
# narsaq
# There is no information for this city: saleaula
# severo-kurilsk
# There is no information for this city: belushya guba
# asandh
# tuatapere
# port elizabeth
# pinawa
# cherskiy
# esperance
# kichera
# santa cruz
# mar del plata
# churapcha
# akdepe
# nikolskoye
# kazachinskoye
# kualakapuas
# honiara
# There is no information for this city: amderma
# barinas
# mitsamiouli
# sur
# stephenville
# kutum
# dandong
# tuktoyaktuk
# bemidji
# doha
# manati
# kawalu
# guiberoua
# yaan
# zhigansk
# kaitangata
# chuy
# shunyi
# flinders
# torbay
# manono
# puntarenas
# rafraf
# petropavlovsk-kamchatskiy
# fortuna
# qaqortoq
# north bend
# velizh
# vardo
# leopold
# brae
# marawi
# bonnyville
# kendari
# rocky mountain house
# vestmanna
# marienburg
# lichinga
# cabo san lucas
# putat
# charters towers
# nouadhibou
# ambulu
# rocha
# iqaluit
# harper
# sarangani
# port hedland
# krasnovishersk
# los alamos
# ojinaga
# san patricio
# north guwahati
# There is no information for this city: nizhneyansk
# camocim
# yellowknife
# tautira
# lorengau
# cidreira
# hobyo
# juan lacaze
# sola
# muncar
# alofi
# There is no information for this city: utiroa
# manokwari
# goya
# nuuk
# dingle
# veraval
# namatanai
# lebu
# arkhara
# coahuayana
# zharkent
# sitka
# There is no information for this city: phrai bung
# souillac
# bethel
# meiktila
# qinhuangdao
# meadow lake
# clyde river
# saint anthony
# ludwigslust
# finspang
# kloulklubed
# There is no information for this city: aktash
# soe
# benguela
# pangody
# rio novo
# andros town
# delhi
# woodward
# college
# whitehorse
# mackay
# sri aman
# adjumani
# ossora
# faya
# toccoa
# There is no information for this city: armacao dos buzios
# guerrero negro
# abadan
# san ignacio
# leh
# airai
# pouebo
# anadyr
# tsabong
# yiyang
# beringovskiy
# carnarvon
# richards bay
# santa maria do suacui
# xam nua
# kovdor
# redmond
# kulunda
# huilong
# la rioja
# tazovskiy
# waitati
# saint george
# yershichi
# la ronge
# inuvik
# yar-sale
# atyrau
# There is no information for this city: ondorhaan
# emerald
# parintins
# goundam
# lillooet
# berdigestyakh
# There is no information for this city: tasbuget
# segovia
# sinnamary
# hami
# kourou
# tucuman
# aswan
# yarada
# antofagasta
# urengoy
# There is no information for this city: warqla
# There is no information for this city: hihifo
# bembereke
# There is no information for this city: bolshoy tsaryn
# pizarro
# porto san giorgio
# mitu
# bayan
# saint-francois
# kuusamo
# acapulco
# almaznyy
# tahe
# muros
# margate
# tual
# the valley
# otradnoye
# ixtapa
# mount isa
# pacifica
# gamba
# cayenne
# erzin
# chernyshevskiy
# quatre cocos
# masallatah
# taoudenni
# longyearbyen
# kondinskoye
# pacific grove
# blagoveshchensk
# bhilwara
# svobodnyy
# sao joao da barra
# sherwood
# taltal
# roma
# palmer
# faanui
# ondjiva
# There is no information for this city: bur gabo
# arman
# aklavik
# victoria
# bend
# santa cruz de la palma
# pevek
# bourges
# rio grande
# karratha
# luangwa
# mercedes
# tasiilaq
# pisco
# omsukchan
# There is no information for this city: tsihombe
# liverpool
# changping
# There is no information for this city: marcona
# There is no information for this city: angra
# There is no information for this city: palabuhanratu
# vila
# la vega
# belmonte
# vanavara
# kavieng
# alice springs
# dunedin
# bambanglipuro
# okhotsk
# salisbury
# marystown
# kununurra
# naron
# dunmore town
# los llanos de aridane
# vangaindrano
# There is no information for this city: olafsvik
# There is no information for this city: asau
# fredonia
# port lincoln
# rovaniemi
# carutapera
# umba
# hasaki
# zhaotong
# porbandar
# yukhnov
# hambantota
# vila velha
# meulaboh
# gravdal
# muroto
# irece
# There is no information for this city: shcholkine
# juegang
# saint-georges
# susanville
# There is no information for this city: krasnoselkup
# klaksvik
# itoman
# nowy dwor mazowiecki
# mayo
# barcelos
# naklo nad notecia
# saldanha
# There is no information for this city: meyungs
# belyy yar
# xique-xique
# grafton
# itarema
# port hardy
# san-pedro
# dolgorukovo
# usinsk
# san matias
# guiglo
# pringsewu
# ouesso
# marathon
# There is no information for this city: vaitupu
# portland
# nabire
# concepcion del uruguay
# reo
# mehamn
# labuhan
# kishapu
# the pas
# laramie
# serenje
# coruripe
# shanghai
# san juan
# weyburn
# kaihua
# sioux lookout
# noumea
# manado
# moose factory
# zemio
# miraflores
# tabas
# ayna
# la palma
# shimoda
# aksarka
# tilichiki
# jiuquan
# north platte
# matay
# lata
# shahrud
# constitucion
# bay roberts
# lakhimpur
# lengshuitan
# thunder bay
# There is no information for this city: jabiru
# natal
# kapit
# ahipara
# sena madureira
# choya
# linxia
# yumen
# general pico
# egvekinot
# There is no information for this city: solsvik
# lasa
# sao jose da coroa grande
# cabadiangan
# singaraja
# kahului
# graham
# mayumba
# saint-joseph
# cabra
# There is no information for this city: burica
# There is no information for this city: mys shmidta
# There is no information for this city: zaplyusye
# trincomalee
# concepcion del oro
# parabel
# kirkland lake
# yulara
# There is no information for this city: gangotri
# cam ranh
# san cristobal
# kastamonu
# sompeta
# vanimo
# turayf
# fort frances
# There is no information for this city: andenes
# port moresby
# bathsheba
# massaguet
# kailua
# ambon
# beberibe
# sao paulo de olivenca
# nhulunbuy
# san quintin
# bulaevo
# leningradskiy
# honningsvag
# grand baie
# laem sing
# There is no information for this city: urumqi
# azanka
# voi
# kupang
# anzio
# calvinia
# There is no information for this city: tumannyy
# abha
# saskylakh
# pocao de pedras
# tura
# medea
# bhopal
# There is no information for this city: sofiysk
# axim
# hirara
# husavik
# lima
# pontes e lacerda
# tessalit
# There is no information for this city: amatlan
# pumiao
# mulchen
# maniitsoq
# berlevag
# la maddalena
# There is no information for this city: pemangkat
# havoysund
# carnaiba
# tampa
# provideniya
# kasongo-lunda
# bereda
# ishigaki
# ola
# miri
# There is no information for this city: ijaki
# qasigiannguit
# There is no information for this city: ituni
# There is no information for this city: aflu
# buxton
# There is no information for this city: viligili
# den helder
# boddam
# sladkovo
# dawlatabad
# bolkhov
# kudahuvadhoo
# nanortalik
# kamenka
# vung tau
# daru
# bilma
# rosarito
# bogotol
# rajshahi
# aberdeen
# haines junction
# omboue
# constantine
# komyshuvakha
# phangnga
# ulaangom
# norrkoping
# samana
# san marco in lamis
# kattivakkam
# zeya
# hokitika
# garowe
# There is no information for this city: barawe
# khandyga
# spirit river
# dallas
# ballinasloe
# nantucket
# makakilo city
# seoul
# kitimat
# negrasi
# There is no information for this city: lolua
# maldonado
# portree
# liepaja
# lingao
# nizwa
# reyes
# pangoa
# ajdabiya
# tadine
# There is no information for this city: gardan diwal
# bajil
# prince george
# pervomayskoye
# kelvington
# kimbe
# There is no information for this city: maghama
# scottsbluff
# pitsunda
# santa rosa
# iquique
# khonsa
# lagoa
# okha
# grand gaube
# christchurch
# angoram
# aguachica
# coquimbo
# touros

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dict={
    "City":name,
    "Latitude":lat,
    "Longitude":lng,
    "Temperature °F":temp,
    "Humidity":hum,
    "Wind Speed":wind,
    "Cloudiness":cloud
}

# %%
city_df=pd.DataFrame(city_dict)
city_df.head(10)
# Out:
#               City  Latitude  Longitude  Temperature °F  Humidity  Wind Speed  \
# 0        Upernavik     72.79     -56.15           31.26        53        8.81
# 1  Arraial do Cabo    -22.97     -42.02           70.91        98        5.68
# 2          Talnakh     69.49      88.39           21.20        85        6.71
# 3           Dafeng     33.20     120.46           72.68        46        6.89
# 4           Hobart    -42.88     147.33           55.47        62        9.17
# 5             Hilo     19.71    -155.08           73.11        65        3.36
# 6         Khatanga     71.98     102.47           18.43        90        3.65
# 7          Qaanaaq     77.48     -69.36           19.29        65       10.74
# 8         Chumikan     54.72     135.31           38.08        82        4.81
# 9             Nome     30.04     -94.42           67.77        88        4.47
#
#    Cloudiness
# 0           0
# 1         100
# 2           0
# 3          92
# 4          75
# 5          40
# 6          79
# 7          85
# 8          12
# 9           1

# %%
output_file=city_df.to_csv("output_file")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_df["Temperature °F"],city_df["Latitude"],edgecolors="black",facecolors="aqua")
plt.title("Latitude vd. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_df["Temperature °F"],city_df["Humidity"],edgecolors="black",facecolors="darkorange")
plt.title("Latitude vd. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df["Temperature °F"],city_df["Cloudiness"],edgecolors="black",facecolors="snow")
plt.title("Latitude vd. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df["Temperature °F"],city_df["Wind Speed"],edgecolors="black",facecolors="steelblue")
plt.title("Latitude vd. Cloudiness Plots")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
